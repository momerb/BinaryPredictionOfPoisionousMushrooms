# %%
import pandas as pd
import joblib

# %%
df = pd.read_pickle('../data/processed/2_test.pkl')

# %%
df
# Out:
#               id  cap-diameter  stem-height  stem-width  cap-shape_b  \
# 0        3116945          8.64        11.13       17.12        False
# 1        3116946          6.90         1.27       10.75        False
# 2        3116947          2.00         6.18        3.14         True
# 3        3116948          3.47         4.98        8.51        False
# 4        3116949          6.17         6.73       13.70        False
# ...          ...           ...          ...         ...          ...
# 2077959  5194904          0.88         2.67        1.35        False
# 2077960  5194905          3.12         2.69        7.38        False
# 2077961  5194906          5.73         6.16        9.74        False
# 2077962  5194907          5.03         6.00        3.46         True
# 2077963  5194908         15.51         2.69       17.71        False
#
#          cap-shape_c  cap-shape_f  cap-shape_o  cap-shape_p  cap-shape_s  ...  \
# ...

# %%
df_pred = df.drop(columns=['id'])

df_pred
# Out:
#          cap-diameter  stem-height  stem-width  cap-shape_b  cap-shape_c  \
# 0                8.64        11.13       17.12        False        False
# 1                6.90         1.27       10.75        False        False
# 2                2.00         6.18        3.14         True        False
# 3                3.47         4.98        8.51        False        False
# 4                6.17         6.73       13.70        False        False
# ...               ...          ...         ...          ...          ...
# 2077959          0.88         2.67        1.35        False        False
# 2077960          3.12         2.69        7.38        False        False
# 2077961          5.73         6.16        9.74        False        False
# 2077962          5.03         6.00        3.46         True        False
# 2077963         15.51         2.69       17.71        False        False
#
#          cap-shape_f  cap-shape_o  cap-shape_p  cap-shape_s  cap-surface_d  \
# ...

# %%
rf_classifier = joblib.load('../models/rf_classifier_model.pkl')

# %%
labels = rf_classifier.predict(df_pred)

labels
# Out:
# array([False,  True,  True, ...,  True, False, False])

# %%
df['class'] = labels

# %%
df['class'].value_counts()
# Out:
# class
# True     1132414
# False     943085
# Name: count, dtype: int64

# %%
df_test = pd.read_pickle('../data/processed/1_test.pkl')

# %%
df_test
# Out:
#               id class  cap-diameter cap-shape cap-surface cap-color  \
# 0        3116945   NaN          8.64         x           t         n
# 1        3116946   NaN          6.90         o           t         o
# 2        3116947   NaN          2.00         b           g         n
# 3        3116948   NaN          3.47         x           t         n
# 4        3116949   NaN          6.17         x           h         y
# ...          ...   ...           ...       ...         ...       ...
# 2077959  5194904   NaN          0.88         x           g         w
# 2077960  5194905   NaN          3.12         x           s         w
# 2077961  5194906   NaN          5.73         x           e         e
# 2077962  5194907   NaN          5.03         b           g         n
# 2077963  5194908   NaN         15.51         f           t         w
#
#         does-bruise-or-bleed gill-attachment gill-color  stem-height  \
# ...

# %%
df
# Out:
#               id  cap-diameter  stem-height  stem-width  cap-shape_b  \
# 0        3116945          8.64        11.13       17.12        False
# 1        3116946          6.90         1.27       10.75        False
# 2        3116947          2.00         6.18        3.14         True
# 3        3116948          3.47         4.98        8.51        False
# 4        3116949          6.17         6.73       13.70        False
# ...          ...           ...          ...         ...          ...
# 2077959  5194904          0.88         2.67        1.35        False
# 2077960  5194905          3.12         2.69        7.38        False
# 2077961  5194906          5.73         6.16        9.74        False
# 2077962  5194907          5.03         6.00        3.46         True
# 2077963  5194908         15.51         2.69       17.71        False
#
#          cap-shape_c  cap-shape_f  cap-shape_o  cap-shape_p  cap-shape_s  ...  \
# ...

# %%
2077964 - 2075499
# Out:
# 2465

# %%
df_final = pd.merge(df_test[['id']], df[['id', 'class']], on='id', how='left')

df_final['class'].value_counts(), df_final['class'].isnull().sum()
# Out:
# (class
#  True     1132414
#  False     943085
#  Name: count, dtype: int64,
#  np.int64(2465))

# %%
1132414 + 2465
# Out:
# 1134879

# %%
pd.set_option('future.no_silent_downcasting', True)

df_final['class'] = df_final['class'].fillna(True)

df_final['class'].value_counts()
# Out:
# class
# True     1134879
# False     943085
# Name: count, dtype: int64

# %%
df_final
# Out:
#               id  class
# 0        3116945  False
# 1        3116946   True
# 2        3116947   True
# 3        3116948   True
# 4        3116949  False
# ...          ...    ...
# 2077959  5194904   True
# 2077960  5194905   True
# 2077961  5194906   True
# 2077962  5194907  False
# 2077963  5194908  False
#
# [2077964 rows x 2 columns]

# %%
df_final['class'] = df_final['class'].map({True: 'p', False: 'e'})

df_final
# Out:
#               id class
# 0        3116945     e
# 1        3116946     p
# 2        3116947     p
# 3        3116948     p
# 4        3116949     e
# ...          ...   ...
# 2077959  5194904     p
# 2077960  5194905     p
# 2077961  5194906     p
# 2077962  5194907     e
# 2077963  5194908     e
#
# [2077964 rows x 2 columns]

# %%
df_final.to_csv('../data/processed/submission_1.csv', index=False)
